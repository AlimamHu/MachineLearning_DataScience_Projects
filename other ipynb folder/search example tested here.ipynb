# %% [markdown]
# SVM
# *  SVM classifiers do not out‐
# put probabilities for each class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris_file=datasets.load_iris()

# %%
X=iris_file.data[:,2:]          #  'petal length (cm)', 'petal width (cm)'
Y=(iris_file.target==2).astype(np.float)    # virginica  true values is 1 & false valuse is 0

# %%
from sklearn.pipeline import Pipeline   # pipeline make step wise step to process certain task
from sklearn.preprocessing import StandardScaler  # standarscaler use for large large margine 
from sklearn.svm import LinearSVC

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
svm_clf=Pipeline([
                  ('stander',StandardScaler())
 ,                 ('svc',LinearSVC(C=1,loss='hinge'))
])

# %%
svm_clf.fit(X,Y)
# Out:
# Pipeline(memory=None,
#          steps=[('stander',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  LinearSVC(C=1, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='hinge', max_iter=1000, multi_class='ovr',
#                            penalty='l2', random_state=None, tol=0.0001,
#                            verbose=0))],
#          verbose=False)

# %%
svm_clf.score(X,Y)
# Out:
# 0.96

# %%
model =LinearSVC(C=1,loss='hinge')

# %%
model.fit(X,Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='hinge', max_iter=1000, multi_class='ovr',
#           penalty='l2', random_state=None, tol=0.0001, verbose=0)

# %%
model.score(X,Y)
# Out:
# 0.96

# %%
polynomial_clf=Pipeline([
                         ('poly_feature', PolynomialFeatures(degree=13)),
                         ('stander',StandardScaler()),
                         ('linearsvm',LinearSVC(C=10,loss='hinge'))
])

# %%
polynomial_clf.fit(X,Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(memory=None,
#          steps=[('poly_feature',
#                  PolynomialFeatures(degree=13, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('stander',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linearsvm',
#                  LinearSVC(C=10, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='hinge', max_iter=1000, multi_class='ovr',
#                            penalty='l2', random_state=None, tol=0.0001,
#                            verbose=0))],
#          verbose=False)

# %%
polynomial_clf.score(X,Y)
# Out:
# 0.9666666666666667

# %%
poly_x=PolynomialFeatures(degree=3)

# %%
model.fit(poly_x.fit_transform(X),Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='hinge', max_iter=1000, multi_class='ovr',
#           penalty='l2', random_state=None, tol=0.0001, verbose=0)

# %%
model.score(poly_x.fit_transform(X),Y)
# Out:
# 0.96

# %%
from sklearn.svm import SVC

# %%
model_SVC=SVC(kernel='poly')

# %%
X[:5]
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2]])

# %%
from sklearn.utils import shuffle

# %%
from sklearn.datasets import make_moons

# %%
X_,y_=make_moons(n_samples=100,shuffle=True,random_state=True)

# %%
X_
# Out:
# array([[ 1.34536505e+00, -4.38468422e-01],
#        [ 1.57211666e+00, -3.20172255e-01],
#        [-5.18392568e-01,  8.55142763e-01],
#        [ 1.40478334e+00, -4.14412623e-01],
#        [ 1.92691676e+00,  1.24732995e-01],
#        [ 4.62538290e-01,  8.86599306e-01],
#        [-6.72300890e-01,  7.40277997e-01],
#        [ 1.46253829e+00, -3.86599306e-01],
#        [ 6.54634946e-01, -4.38468422e-01],
#        [ 4.27883340e-01, -3.20172255e-01],
#        [ 1.90096887e+00,  6.61162609e-02],
#        [-8.01413622e-01,  5.98110530e-01],
#        [ 7.30832427e-02,  1.24732995e-01],
#        [ 8.20998618e-03,  3.72122838e-01],
#        [ 2.05460725e-03,  4.35929780e-01],
#        [-4.62538290e-01,  8.86599306e-01],
#        [-4.04783343e-01,  9.14412623e-01],
#        [-9.49055747e-01,  3.15108218e-01],
#        [ 1.22252093e+00, -4.74927912e-01],
#        [ 8.01413622e-01,  5.98110530e-01],
#        [ 9.91790014e-01,  1.27877162e-01],
#        [ 9.03976974e-01, -4.95379113e-01],
# ...

# %%
    plt.scatter(X_[:,0],y_)

# %%
from sklearn.datasets import fetch_openml

# %%
# %time mnist=fetch_openml('mnist_784',version=1)
# Out:
# CPU times: user 19.8 s, sys: 398 ms, total: 20.2 s
# Wall time: 20.2 s

# %%
import  pandas  as  pd 
from  IPython.display  import  display # create a simple dataset of people 
data  =  {'Name':  ["John",  "Anna",  "Peter",  "Linda"], 
'Location'  :  ["New York",  "Paris",  "Berlin",  "London"],
 'Age'  :  [24,  13,  53,  33] } 
data_pandas  =  pd.DataFrame(data)
# IPython.display allows "pretty printing" of dataframes # in the Jupyter notebook 
display(data_pandas)
# Out:
#     Name  Location  Age
# 0   John  New York   24
# 1   Anna     Paris   13
# 2  Peter    Berlin   53
# 3  Linda    London   33
