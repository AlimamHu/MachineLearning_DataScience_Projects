# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import lxml

# %% [markdown]
# # Assingment 1

# %% [markdown]
# # High number of patents across the country in the world.

# %%
all_country_patent=pd.read_csv('drive/MyDrive/Colab Notebooks/application_patent.csv')

# %%
all_country_patent
# Out:
#                    Country  ...  2018 Patent applications[7]
# 0                    China  ...                    1,542,002
# 1                     U.S.  ...                      597,141
# 2                    Japan  ...                      313,567
# 3              South Korea  ...                      209,992
# 4   European Patent Office  ...                      174,397
# 5                  Germany  ...                       67,898
# 6                    India  ...                       50,055
# 7       Russian Federation  ...                       37,957
# 8                   Canada  ...                       36,161
# 9                Australia  ...                       29,957
# 10                  Brazil  ...                       24,857
# 11          United Kingdom  ...                       20,941
# 12                  Mexico  ...                       16,424
# 13                  France  ...                     16,222 1
# ...

# %%
plt.barh(all_country_patent['Country'],all_country_patent['2019 Patent applications'])
plt.xticks(rotation=45)
plt.xlabel('no. patents')
plt.ylabel('country')
plt.show()

# %%
all_country_patent.sort_values('2019 Patent applications',ascending=False)
# Out:
#                    Country  ...  2018 Patent applications[7]
# 0                    China  ...                    1,542,002
# 1                     U.S.  ...                      597,141
# 2                    Japan  ...                      313,567
# 3              South Korea  ...                      209,992
# 4   European Patent Office  ...                      174,397
# 5                  Germany  ...                       67,898
# 6                    India  ...                       50,055
# 8                   Canada  ...                       36,161
# 7       Russian Federation  ...                       37,957
# 9                Australia  ...                       29,957
# 10                  Brazil  ...                       24,857
# 11          United Kingdom  ...                       20,941
# 14    China, Hong Kong SAR  ...                       15,986
# 12                  Mexico  ...                       16,424
# ...

# %%
top_five_country=all_country_patent.sort_values('2019 Patent applications',ascending=False).head(5)

# %%
top_five_country
# Out:
#                   Country  2019 Rank  ...  2018 Rank [7]  2018 Patent applications[7]
# 0                   China          1  ...              1                    1,542,002
# 1                    U.S.          2  ...              2                      597,141
# 2                   Japan          3  ...              3                      313,567
# 3             South Korea          4  ...              4                      209,992
# 4  European Patent Office          5  ...              5                      174,397
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Top five Country in world

# %%
plt.barh(top_five_country['Country'],top_five_country['2019 Patent applications'])
plt.xlabel('number of patents')
plt.ylabel('Country')
plt.title('top 5 Country ')
plt.show()

# %% [markdown]
# ### China have highest patents in world

# %%
data_file_url=pd.read_html(r'https://www.wipo.int/ipstats/en/statistics/country_profile/profile.jsp?code=CN')

# %%
len(data_file_url)
# Out:
# 21

# %%
china_patend_data=data_file_url[2]

# %%
china_patend_data.columns=china_patend_data.loc[0]

# %%
china_patend_data=china_patend_data.drop(0,axis=0)

# %% [markdown]
# ###  china past 10 year  data, Number of patents with GDP

# %%
china_patend_data
# Out:
# 0   Year   Patent  ... Industrial Design (design count) GDP (Constant 2017 US$)
# 1   2011   436186  ...                           563863                13020.07
# 2   2012   561472  ...                           718125                14043.93
# 3   2013   734115  ...                           765221                15134.61
# 4   2014   837857  ...                           677313                16258.47
# 5   2015  1010557  ...                           730511                17403.28
# 6   2016  1257466  ...                           794083                18595.19
# 7   2017  1306077  ...                           862643                19887.03
# 8   2018  1460243  ...                           957372                21229.36
# 9   2019  1328067  ...                          1118565                22492.45
# 10  2020  1441085  ...                          1336233                23009.78
#
# [10 rows x 5 columns]

# %%
china_patend_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 1 to 10
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              10 non-null     object
#  1   Patent                            10 non-null     object
#  2   Trademark (class count)           10 non-null     object
#  3   Industrial Design (design count)  10 non-null     object
#  4   GDP (Constant 2017 US$)           10 non-null     object
# dtypes: object(5)
# memory usage: 480.0+ bytes

# %% [markdown]
# converting dataType into (int & float)

# %%
china_patend_data['Patent']=china_patend_data['Patent'].astype(int)
china_patend_data['Trademark (class count)']=china_patend_data['Trademark (class count)'].astype(int)
china_patend_data['Industrial Design (design count)']=china_patend_data['Industrial Design (design count)'].astype(int)
china_patend_data['GDP (Constant 2017 US$)']=china_patend_data['GDP (Constant 2017 US$)'].astype(float)

# %%
china_patend_data['Year']=pd.to_datetime(china_patend_data.Year).dt.year

# %%
china_patend_data
# Out:
# 0   Year   Patent  ...  Industrial Design (design count)  GDP (Constant 2017 US$)
# 1   2011   436186  ...                            563863                 13020.07
# 2   2012   561472  ...                            718125                 14043.93
# 3   2013   734115  ...                            765221                 15134.61
# 4   2014   837857  ...                            677313                 16258.47
# 5   2015  1010557  ...                            730511                 17403.28
# 6   2016  1257466  ...                            794083                 18595.19
# 7   2017  1306077  ...                            862643                 19887.03
# 8   2018  1460243  ...                            957372                 21229.36
# 9   2019  1328067  ...                           1118565                 22492.45
# 10  2020  1441085  ...                           1336233                 23009.78
#
# [10 rows x 5 columns]

# %%
sns.pairplot(china_patend_data)

# %%
china_patend_data.corr()
# Out:
# 0                                     Year  ...  GDP (Constant 2017 US$)
# 0                                           ...
# Year                              1.000000  ...                 0.998583
# Patent                            0.962931  ...                 0.962212
# Trademark (class count)           0.961358  ...                 0.962764
# Industrial Design (design count)  0.906420  ...                 0.899338
# GDP (Constant 2017 US$)           0.998583  ...                 1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ### increasing GDP impact to Patent values may be it increase it values

# %%
plt.scatter(china_patend_data['Patent'],china_patend_data['GDP (Constant 2017 US$)'])
plt.xlabel('Patent')
plt.ylabel('GDP US $')
plt.title('as Increasing GDP will increase no. Patests')
plt.show()

# %% [markdown]
# ### **GDP** is good **Factor** , because China have high number of patents across the country in the world.

# %% [markdown]
# # Assingment 2

# %% [markdown]
# # 1) compair with the other country

# %%
data_compair=pd.read_csv('drive/MyDrive/Colab Notebooks/DP_LIVE_23112021155617807.csv')

# %%
data_compair
# Out:
#       LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0          AUS   GDEXPRD     TOT  PC_GDP         A  2017  1.788527         NaN
# 1          AUT   GDEXPRD     TOT  PC_GDP         A  2017  3.056734         NaN
# 2          AUT   GDEXPRD     TOT  PC_GDP         A  2018  3.091081         NaN
# 3          AUT   GDEXPRD     TOT  PC_GDP         A  2019  3.129277         NaN
# 4          AUT   GDEXPRD     TOT  PC_GDP         A  2020  3.218447         NaN
# ..         ...       ...     ...     ...       ...   ...       ...         ...
# 127        COL   GDEXPRD     TOT  PC_GDP         A  2018  0.311522         NaN
# 128        COL   GDEXPRD     TOT  PC_GDP         A  2019  0.319731         NaN
# 129  EU27_2020   GDEXPRD     TOT  PC_GDP         A  2017  2.031696         NaN
# 130  EU27_2020   GDEXPRD     TOT  PC_GDP         A  2018  2.074322         NaN
# 131  EU27_2020   GDEXPRD     TOT  PC_GDP         A  2019  2.115075         NaN
#
# [132 rows x 8 columns]

# %%
data_compair.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    132 non-null    object
#  1   INDICATOR   132 non-null    object
#  2   SUBJECT     132 non-null    object
#  3   MEASURE     132 non-null    object
#  4   FREQUENCY   132 non-null    object
#  5   TIME        132 non-null    int64
#  6   Value       132 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 8.4+ KB

# %%
data_compair=data_compair[data_compair['TIME']==2019]

# %%
data_compair.head(3)
# Out:
#    LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 3       AUT   GDEXPRD     TOT  PC_GDP         A  2019  3.129277         NaN
# 7       BEL   GDEXPRD     TOT  PC_GDP         A  2019  3.172059         NaN
# 10      CAN   GDEXPRD     TOT  PC_GDP         A  2019  1.591631         NaN

# %%
data_compair=data_compair.drop(['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY','Flag Codes'],axis=1)

# %%
data_compair=data_compair.reset_index()

# %%
data_compair=data_compair.drop('index',axis=1)

# %%
data_compair
# Out:
#      LOCATION  TIME     Value
# 0         AUT  2019  3.129277
# 1         BEL  2019  3.172059
# 2         CAN  2019  1.591631
# 3         CZE  2019  1.941657
# 4         DNK  2019  2.912160
# 5         FIN  2019  2.794919
# 6         FRA  2019  2.196254
# 7         DEU  2019  3.190021
# 8         GRC  2019  1.274530
# 9         HUN  2019  1.477569
# 10        ISL  2019  2.325272
# 11        IRL  2019  1.228237
# 12        ITA  2019  1.466249
# 13        JPN  2019  3.198993
# 14        KOR  2019  4.640189
# 15        LUX  2019  1.132779
# 16        MEX  2019  0.283967
# 17        NLD  2019  2.184354
# 18        NZL  2019  1.412667
# 19        NOR  2019  2.153024
# 20        POL  2019  1.320635
# 21        PRT  2019  1.398399
# 22        SVK  2019  0.827035
# 23        ESP  2019  1.250992
# 24        SWE  2019  3.387582
# 25        TUR  2019  1.063696
# 26        GBR  2019  1.755940
# 27        USA  2019  3.067476
# 28        ARG  2019  0.464695
# 29        CHN  2019  2.234772
# ...

# %%
data_compair.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  41 non-null     object
#  1   TIME      41 non-null     int64
#  2   Value     41 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
sum(data_compair['LOCATION']=='IND')
# Out:
# 0

# %%
data_compair.loc[len(data_compair.index)] = ['IND', 2019,0.7]

# %%
data_compair
# Out:
#      LOCATION  TIME     Value
# 0         AUT  2019  3.129277
# 1         BEL  2019  3.172059
# 2         CAN  2019  1.591631
# 3         CZE  2019  1.941657
# 4         DNK  2019  2.912160
# 5         FIN  2019  2.794919
# 6         FRA  2019  2.196254
# 7         DEU  2019  3.190021
# 8         GRC  2019  1.274530
# 9         HUN  2019  1.477569
# 10        ISL  2019  2.325272
# 11        IRL  2019  1.228237
# 12        ITA  2019  1.466249
# 13        JPN  2019  3.198993
# 14        KOR  2019  4.640189
# 15        LUX  2019  1.132779
# 16        MEX  2019  0.283967
# 17        NLD  2019  2.184354
# 18        NZL  2019  1.412667
# 19        NOR  2019  2.153024
# 20        POL  2019  1.320635
# 21        PRT  2019  1.398399
# 22        SVK  2019  0.827035
# 23        ESP  2019  1.250992
# 24        SWE  2019  3.387582
# 25        TUR  2019  1.063696
# 26        GBR  2019  1.755940
# 27        USA  2019  3.067476
# 28        ARG  2019  0.464695
# 29        CHN  2019  2.234772
# ...

# %%
plt.figure(figsize=(12,3))
plt.bar(data_compair['LOCATION'],data_compair['Value'],)
plt.xlabel('Country code ')
plt.title('Percent of GDP spend on Science and Technology, Few country')
plt.ylabel(' % of GDP spent on Science and Technology')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 2) correlation find between S&T spending and developmental indicators

# %%
hdi_ranking_india=pd.read_html('https://countryeconomy.com/hdi/india')

# %%
hdi_ranking_india=hdi_ranking_india[0]

# %%
hdi_ranking_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         30 non-null     int64
#  1   HDI          30 non-null     float64
#  2   HDI Ranking  30 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 848.0+ bytes

# %% [markdown]
# ### Percentage of GDP spending on Science & Technoledge

# %%
SandT_values=pd.read_csv('drive/MyDrive/Colab Notebooks/worldBank_historical.csv')

# %%
SandT_values
# Out:
#                    date    value
# 0   1996-06-15T00:00:00  0.62804
# 1   1997-06-15T00:00:00  0.67485
# 2   1998-06-15T00:00:00  0.69166
# 3   1999-06-15T00:00:00  0.71165
# 4   2000-06-15T00:00:00  0.74395
# 5   2001-06-15T00:00:00  0.72323
# 6   2002-06-15T00:00:00  0.71316
# 7   2003-06-15T00:00:00  0.70689
# 8   2004-06-15T00:00:00  0.74385
# 9   2005-06-15T00:00:00  0.81044
# 10  2006-06-15T00:00:00  0.79722
# 11  2007-06-15T00:00:00  0.79080
# 12  2008-06-15T00:00:00  0.84108
# 13  2009-06-15T00:00:00  0.81881
# 14  2010-06-15T00:00:00  0.79718
# 15  2011-06-15T00:00:00  0.82224
# 16  2012-06-15T00:00:00  0.74399
# 17  2013-06-15T00:00:00  0.70642
# 18  2014-06-15T00:00:00  0.70159
# 19  2015-06-15T00:00:00  0.69310
# 20  2016-06-15T00:00:00  0.67111
# 21  2017-06-15T00:00:00  0.66584
# 22  2018-06-15T00:00:00  0.64998

# %%
SandT_values['Date']=pd.to_datetime(SandT_values.date).dt.year

# %%
SandT_values=SandT_values=SandT_values.drop('date',axis=1)

# %%
display(SandT_values)
display(hdi_ranking_india)
# Out:
#       value  Date
# 0   0.62804  1996
# 1   0.67485  1997
# 2   0.69166  1998
# 3   0.71165  1999
# 4   0.74395  2000
# 5   0.72323  2001
# 6   0.71316  2002
# 7   0.70689  2003
# 8   0.74385  2004
# 9   0.81044  2005
# 10  0.79722  2006
# 11  0.79080  2007
# 12  0.84108  2008
# 13  0.81881  2009
# 14  0.79718  2010
# 15  0.82224  2011
# 16  0.74399  2012
# 17  0.70642  2013
# 18  0.70159  2014
# 19  0.69310  2015
# 20  0.67111  2016
# 21  0.66584  2017
# 22  0.64998  2018
#     Date    HDI HDI Ranking
# 0   2019  0.645        131º
# 1   2018  0.642        131º
# 2   2017  0.640        131º
# 3   2016  0.630        130º
# 4   2015  0.624        131º
# 5   2014  0.616        132º
# 6   2013  0.604        134º
# 7   2012  0.597        134º
# 8   2011  0.588        135º
# 9   2010  0.579        135º
# 10  2009  0.569        135º
# 11  2008  0.563        135º
# 12  2007  0.555        135º
# 13  2006  0.546        135º
# 14  2005  0.536        135º
# 15  2004  0.527        130º
# ...

# %%
NEW_DATA_FOR_CORRELATION=pd.merge(SandT_values,hdi_ranking_india,on='Date')

# %%
NEW_DATA_FOR_CORRELATION.corr()
# Out:
#           value      Date       HDI
# value  1.000000  0.028313  0.016416
# Date   0.028313  1.000000  0.998724
# HDI    0.016416  0.998724  1.000000

# %%
sns.pairplot(NEW_DATA_FOR_CORRELATION)

# %%
NEW_DATA_FOR_CORRELATION.head(5)
# Out:
#      value  Date    HDI HDI Ranking
# 0  0.62804  1996  0.468        114º
# 1  0.67485  1997  0.474        112º
# 2  0.69166  1998  0.481        112º
# 3  0.71165  1999  0.489        110º
# 4  0.74395  2000  0.495        127º

# %%
plt.scatter(NEW_DATA_FOR_CORRELATION['value'],NEW_DATA_FOR_CORRELATION['HDI'])
plt.xlabel('India govt. S&T spending ')
plt.ylabel('Human Development Index (HDI)')
plt.title('Correlation between S&T and HDI is 0.016416')
plt.show()

# %% [markdown]
# Correlation between **Science & Technoledge** and **HDI** is 0.016416
