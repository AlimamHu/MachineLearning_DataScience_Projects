# %% [markdown]
# we used the **correlation function** to measure the strength of the linearrelationship between **two variables**

# %%
import numpy as np

# %%
def predict(alpha,beta,x_i):        # this function give y estimate
    return beta*x_i+ alpha              # alpha is also constant

# %%
def error(alpha,beta,x_i,y_i):   # error function find the distance between estimated & true  values
    return y_i - predict(beta*x_i+ alpha)# in the error function we call the predict function which estimated values which are substract real values

# %%
def sum_of_square(alpha,beta,x,y):    #not higher values cancel out lower values
    return sum(error(alpha,beta,x_i,y_i)**2 for x_i,y_i in zip(x,y))  # now error function call

# %%
def least_square(x,y): # this function give the alpha beta
    beta=np.corrcoef(x,y)*np.std(y)/np.std(x)
    alpha=np.mean(y) -beta*np.mean(x)
    return beta, alpha

# %%
#@title
users = [
{
 "id":
 0,
 "name":
 "Hero" },
{
 "id":
 1,
 "name":
 "Dunn" },
{
 "id":
 2,
 "name":
 "Sue" },
{
 "id":
 3,
 "name":
 "Chi" },
{
 "id":
 4,
 "name":
 "Thor" },
{
 "id":
 5,
 "name":
 "Clive" },
{
 "id":
 6,
 "name":
 "Hicks" },
{
 "id":
 7,
 "name":
 "Devin" },
{
 "id":
 8,
 "name":
 "Kate" },
{
 "id":
 9,
 "name":
 "Klein" }
]

# %%
friendships = [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3), (3, 4),
(4, 5), (5, 6), (5, 7), (6, 8), (7, 8), (8, 9)]

# %%
for user in users:
    user['friends']=[]   #    {'id': 0, 'name': 'Hero'}['friends]=[]

# %%
for i, j in friendships:
# this works because users[i] is the user whose id is i
    users[i]["friends"].append(users[j]) # add i as a friend of j
    users[j]["friends"].append(users[i]) # add j as a friend of i

# %%
def number_of_user(user):
    return len(user['friends'])

# %%
tow=zip(number_of_user(user) for user in users)

# %%
for i in tow:
    print(i)
# Out:
# (2,)
# (3,)
# (3,)
# (3,)
# (2,)
# (3,)
# (2,)
# (2,)
# (3,)
# (1,)
