# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
# !ls -lh
# Out:
# total 8.0K
# drwx------ 5 root root 4.0K Jun 30 07:57 drive
# drwxr-xr-x 1 root root 4.0K Jun 15 13:37 sample_data

# %%
# os.chdir('drive/MyDrive/dataset/aclImdb/')
print('now :' ,os.getcwd())
# Out:
# now : /content/drive/MyDrive/dataset/aclImdb

# %%
from sklearn.datasets import load_files

# %%
review_data=load_files('train/neg/')

# %%
review_data
# Out:
# {'DESCR': None,
#  'data': [],
#  'filenames': array([], dtype=float64),
#  'target': array([], dtype=float64),
#  'target_names': []}
