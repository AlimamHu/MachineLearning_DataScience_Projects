# %%
import cv2
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img=np.zeros((255,255,3))

# %%
cv2.imshow("image",img)
cv2.waitkey(0)

# %%
img.size
# Out:
# 195075

# %%
img[20:23,32:94]=0,0,255
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
