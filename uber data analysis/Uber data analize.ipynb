# %%
import os 
os.chdir('drive/MyDrive/dataset/')

# %%
cd dataset/
# Out:
# /content/drive/My Drive/dataset

# %%
cd /content/drive/My Drive/dataset/drive/MyDrive/dataset/Kaggle
# Out:
# /content/drive/My Drive/dataset/drive/MyDrive/dataset/Kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/dataset/drive/MyDrive/dataset/Kaggle"

# %%
# !kaggle datasets download -d fivethirtyeight/uber-pickups-in-new-york-city
# Out:
# ...
# 100% 109M/109M [00:01<00:00, 89.9MB/s]
# 100% 109M/109M [00:01<00:00, 80.4MB/s]

# %%
ls
# Out:
# kaggle.json                          other-Skyline_B00111.csv
# other-American_B01362.csv            Uber-Jan-Feb-FOIL.csv
# other-Carmel_B00256.csv              uber-pickups-in-new-york-city.zip
# other-Dial7_B00887.csv               uber-raw-data-apr14.csv
# other-Diplo_B01196.csv               uber-raw-data-aug14.csv
# other-Federal_02216.csv              uber-raw-data-janjune-15.csv
# other-FHV-services_jan-aug-2015.csv  uber-raw-data-jul14.csv
# other-Firstclass_B01536.csv          uber-raw-data-jun14.csv
# other-Highclass_B01717.csv           uber-raw-data-may14.csv
# other-Lyft_B02510.csv                uber-raw-data-sep14.csv
# other-Prestige_B01338.csv

# %%
import pandas as pd

# %%
final=pd.read_csv('uber-raw-data-janjune-15.csv')

# %%
df =final.copy()

# %%
df.sample(10)
# Out:
#          Dispatching_base_num  ... locationID
# 1193190                B02764  ...         42
# 5051683                B02682  ...        107
# 5215679                B02764  ...         68
# 7010244                B02764  ...         68
# 1782390                B02764  ...        158
# 6476242                B02764  ...         17
# 10197701               B02598  ...        142
# 122839                 B02764  ...         37
# 9377064                B02598  ...        236
# 7612498                B02617  ...        246
#
# [10 rows x 4 columns]

# %%
df.sort_values(by='Dispatching_base_num',ascending=False)
# Out:
#          Dispatching_base_num  ... locationID
# 14122104               B02836  ...         49
# 14121298               B02836  ...         36
# 14121291               B02836  ...         79
# 14121292               B02836  ...        256
# 14121293               B02836  ...         90
# ...                       ...  ...        ...
# 8212675                B02512  ...         79
# 8212676                B02512  ...        163
# 8212677                B02512  ...         87
# 8212678                B02512  ...        236
# 7662081                B02512  ...         36
#
# [14270479 rows x 4 columns]

# %%
so=pd.to_datetime(df['Pickup_date'])

# %%
so.dt.month.value_counts().
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d09d547b77d> in <module>()
# ----> 1 so.dt.month.value_counts().index()
#
# NameError: name 'so' is not defined

# %%
df['Dispatching_base_num'].value_counts()
# Out:
# B02764    5753653
# B02682    3484530
# B02617    2068525
# B02598    1526660
# B02765    1152727
# B02512     255772
# B02835      26622
# B02836       1990
# Name: Dispatching_base_num, dtype: int64
